# %%
# Comprobar las transacciones crudas en Bronze
df_bronze = spark.table("workspace.abandono_carrito_comercio_electronico.bronze_transactions")
print(f"Filas en Bronze: {df_bronze.count()}")
# Out:
# Filas en Bronze: 1
