# %%
# Ver las columnas reales de la tabla de agregaciones
display(spark.table("workspace.abandono_carrito_comercio_electronico.gold_user_behavior_features").limit(1))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
