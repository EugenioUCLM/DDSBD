# %%
# Comprobar los eventos procesados en Silver
df_silver = spark.table("workspace.abandono_carrito_comercio_electronico.silver_abandonment_events")
print(f"Filas en Silver: {df_silver.count()}")
# Out:
# Filas en Silver: 1
