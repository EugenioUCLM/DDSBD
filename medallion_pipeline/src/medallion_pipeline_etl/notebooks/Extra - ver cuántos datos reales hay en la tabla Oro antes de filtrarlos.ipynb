# %%
df_check = spark.table("workspace.abandono_carrito_comercio_electronico.gold_abandonment_spine")
print(f"Filas totales en la Spine: {df_check.count()}")
display(df_check.groupBy("will_abandon").count())
# Out:
# Filas totales en la Spine: 1
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>will_abandon</th><th>count</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>
